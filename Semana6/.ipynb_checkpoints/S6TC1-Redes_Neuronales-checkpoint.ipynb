# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Redes Neuronales
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de redes neuronales de una capa y multicapa. El taller está constituido por 4 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción probabilidad de admisión a la universidad
#
# En este taller se usará el conjunto de datos de admisiones a una universidad proveniente de la base de datos de Kaggle. Cada observación contiene la probabilidad de que un estudiante sea admitido por la universidad, dadas distintas variables predictoras como el puntaje del examén TOEFL y GRE, el promedio (GPA), entre otras. El objetivo es predecir la probabilidad de admissión de cada estudiante. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/mohansacharya/graduate-admissions).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import numpy as np
import keras 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from keras import initializers
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Carga de datos de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/universityGraduateAdmissions.csv', index_col=0)
data = pd.DataFrame(data, columns=data.columns)
data.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
# Histogramas de las varaibles del dataset
data.hist(bins=25, figsize=(15,15))
plt.show()

# %%
# Definición de variables predictoras (X)
X = data.drop(data.columns[-1], axis=1)
# Definición de variable de interés (y)
Y = data[data.columns[-1]]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# %% [markdown]
# ## Punto 1 - Red Neuronal de una capa
#
# En la celda 1 creen una **red neuronal de una capa** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes, usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador y el número de épocas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 1
# Normalización de variables predictoras (X) con la función StandardScaler
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Activation
from livelossplot import PlotLossesKeras
from keras import backend as K
import keras.optimizers as opts

# Definición de la función StandardScaler
scaler = StandardScaler()

# Transformación de los set de entrenamiento y test
xTrain = scaler.fit_transform(xTrain)
xTest = scaler.transform(xTest)

# # Definición de dimensiones de salida
output_var = yTrain.shape[0]
print(output_var, ' output variables')

# # Definición de dimensiones de entrada
dims = xTrain.shape[1]
print(dims, 'input variables')

# #Red neuronal
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(1, input_shape=(dims,)))

#Impresión de la arquitectura de la red neuronal
print(model.summary())

#Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenamiento de la red neuronal con 50 épocas
model.fit(xTrain, yTrain, 
          verbose=1, 
          epochs=100, 
          validation_data=(xTest,yTest),
          callbacks=[PlotLossesKeras()])

#Evaluando el desempeño de la red_neuronal con ADAM
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Predecir las probabilidades de admisión en el conjunto de prueba
yPred = model.predict(xTest)
# Calcular el error absoluto medio (MAE)
mae = mean_absolute_error(yTest, yPred)
print("Error absoluto medio (MAE):", mae)
# Calcular el error cuadrático medio (MSE)
mse = mean_squared_error(yTest, yPred)
print("Error cuadrático medio (MSE):", mse)
# Out:
# Loss
# 	training         	 (min:    0.116, max:    2.778, cur:    0.116)
# 	validation       	 (min:    0.140, max:    2.832, cur:    0.140)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1191 - val_loss: 0.1401
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Error absoluto medio (MAE): 0.28197398105462396
# Error cuadrático medio (MSE): 0.1400694135637859

# %%
#Realizando el mismo ejercicio pero seleccionando como optimizador a RMStrop
model = Sequential()
model.add(Dense(1, input_shape=(dims,)))
#Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='adam', loss='mean_squared_error')
# Entrenamiento de la red neuronal con 50 épocas
model.fit(xTrain, yTrain, 
          verbose=1, 
          epochs=100, 
          validation_data=(xTest,yTest),
          callbacks=[PlotLossesKeras()])

#Evaluando el desempeño de la red_neuronal con RMStrop
yPred = model.predict(xTest)
mae = mean_absolute_error(yTest, yPred)
print("Error absoluto medio (MAE) usando RMStrop:", mae)
mse = mean_squared_error(yTest, yPred)
print("Error cuadrático medio (MSE) usando RMStrop:", mse)
# Out:
# Loss
# 	training         	 (min:    0.025, max:    1.011, cur:    0.025)
# 	validation       	 (min:    0.025, max:    0.975, cur:    0.025)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0253 - val_loss: 0.0247
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002C77ABA9F80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#Realizando el mismo ejercicio pero seleccionando como optimizador a sgd
model = Sequential()
model.add(Dense(1, input_shape=(dims,)))
#Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')
# Entrenamiento de la red neuronal con 50 épocas
model.fit(xTrain, yTrain, 
          verbose=1, 
          epochs=100, 
          validation_data=(xTest,yTest),
          callbacks=[PlotLossesKeras()])

#Evaluando el desempeño de la red_neuronal con RMStrop
yPred = model.predict(xTest)
mae = mean_absolute_error(yTest, yPred)
print("Error absoluto medio (MAE) usando sgd:", mae)
mse = mean_squared_error(yTest, yPred)
print("Error cuadrático medio (MSE) usando sgd:", mse)
# Out:
# Loss
# 	training         	 (min:    0.004, max:    2.202, cur:    0.004)
# 	validation       	 (min:    0.003, max:    1.777, cur:    0.003)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - val_loss: 0.0034
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Error absoluto medio (MAE) usando sgd: 0.04314802696704864
# Error cuadrático medio (MSE) usando sgd: 0.0034080419856307533

# %% [markdown]
# ### JUSTIFICACION DE PUNTO1
# * *SELECCION DE PARAMETROS PARA LA FUNCION DE PERDIDA:* Teniendo presente que el problema que se va resolver en la red neuronal es la predeccion de un valor numerico continuo( la probabilidad de admision), se considera un problema de regresion. la funcion de perdida que se opta por usar es el error absoluto medio (MAE), teniendo presente que dentro de la distribuccion de mi variable objetivo se observaron valores atipicos y se desea que el modelo sea mas robusto a ellos.
#
# Se detemina el uso de 100 epocas con el objetivo de tener un rango amplio para seleccionar la mejor epoca de acuerdo a la estabilziación de los datos de entrenamiento y validación.
#
# Ahora para seleccionar el mejor optmizador segun el tipo de problema, se toma la decision de usar en una primera instancia el optimizador mas popular Y mas rapido en su convergencia (ADAM),Luego se hara la prueba con RMStrop que es el segundo mas rapido en su convergencia y por ultimo el sgd.Observando los resultados obtenidos, se concluye que el sgd es el mejor metodo a usar en este caso, ya que es el que tiene el menor MAE y MSE entre los tres metodos evaluados, es decir, el metodo sgd produce resultados mas precisos y tiene errores de prediccion mas bajos.
# Por otro lado si observamos el grafico del sgd podemos concluir que el modelo se establizo desde la epoca 40. este podria ser un util para emplear con el metodo early stopping.

# %% [markdown]
# ## Punto 2 - Red Neuronal multicapa
#
# En la celda 2 creen una **red neuronal con dos capas** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 2
#PRUEBA 2.1 el optimizador sgd y 40 epocas son escogidas para todas las pruebas, de acuerdo a los resultados del punto 1
#NEURONAS:256,OPTIMIZADOR:SGD,EPOCAS:40.

from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense, Activation
from livelossplot import PlotLossesKeras
from keras import backend as K
import keras.optimizers as opts
from sklearn.metrics import mean_absolute_error, mean_squared_error

#Con base en la normalizacion realizada en el punto 1
# # Definición de dimensiones de salida
output_var = 1
print(output_var, ' output variables')

# # Definición de dimensiones de entrada
dims = xTrain.shape[1]
print(dims, 'input variables')

K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))
# Impresión de la arquitectura de la red neuronal
print(model.summary())

# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
#se escoge sgd debido a que con el se obtuvieron mejores resultados en el punto1 para este set de datos
model.compile(optimizer='sgd', loss='mean_squared_error')
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
xTrain, X_val, yTrain, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)
# Entrenamiento de la red neuronal con 40 épocas, de acuerdo a los resultados obtenidos en el punto1
model.fit(xTrain, yTrain,
          validation_data = (X_val, Y_val),
          epochs=40, 
          callbacks=[PlotLossesKeras()])
#Evaluando el desempeño de la red_neuronal 
yPred2_1 = model.predict(xTest)
mae2_1 = mean_absolute_error(yTest, yPred2_1)
print("Error absoluto medio (MAE) 1:", mae2_1)
mse2_1 = mean_squared_error(yTest, yPred2_1)
print("Error cuadrático medio (MSE) 1:", mse2_1)
# Out:
# Loss
# 	training         	 (min:    0.005, max:    0.461, cur:    0.005)
# 	validation       	 (min:    0.006, max:    0.243, cur:    0.006)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0056 - val_loss: 0.0058
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Error absoluto medio (MAE) 1: 0.06278637839158376
# Error cuadrático medio (MSE) 1: 0.006614071941612282

# %%
#Prueba 2.2 cambiando el numero de neuronas a la mitad 128 teniendo en cuenta que el conjunto de datos no es tan grande (500)
output_var = 1
print(output_var, ' output variables')

# # Definición de dimensiones de entrada
dims = xTrain.shape[1]
print(dims, 'input variables')

K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(128, input_shape=(dims,),activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))
# Impresión de la arquitectura de la red neuronal
print(model.summary())

# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
#se escoge sgd debido a que con el se obtuvieron mejores resultados en el punto1 para este set de datos
model.compile(optimizer='sgd', loss='mean_squared_error')
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
xTrain, X_val, yTrain, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)
# Entrenamiento de la red neuronal con 40 épocas, de acuerdo a los resultados obtenidos en el punto1
model.fit(xTrain, yTrain,
          validation_data = (X_val, Y_val),
          epochs=40, 
          callbacks=[PlotLossesKeras()])
#Evaluando el desempeño de la red_neuronal 
yPred2_2 = model.predict(xTest)
mae2_2 = mean_absolute_error(yTest, yPred2_2)
print("Error absoluto medio (MAE) 2_2:", mae2_2)
mse2_2 = mean_squared_error(yTest, yPred2_2)
print("Error cuadrático medio (MSE) 2_2:", mse2_2)
# Out:
# Loss
# 	training         	 (min:    0.008, max:    0.181, cur:    0.008)
# 	validation       	 (min:    0.007, max:    0.095, cur:    0.007)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0083 - val_loss: 0.0070
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F9EE4B7370> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
#PRUEBA 2.3 Buscando la mejor función de activación
#el optimizador sgd y 40 epocas son escogidas para todas las pruebas, de acuerdo a los resultados del punto 1
#NEURONAS:256,OPTIMIZADOR:SGD,EPOCAS:40
#Con base en la normalizacion realizada en el punto 1

from keras.activations import relu, sigmoid

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,), activation='relu'))  # Capa con función de activación RELU
model.add(Dense(256, activation='relu'))  # Capa con función de activación RELU
model.add(Dense(output_var, activation='relu'))  # Capa de salida con función de activación RELU

# Compilación y entrenamiento para RELU
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xTrain, yTrain, validation_data=(X_val, Y_val), epochs=40, callbacks=[PlotLossesKeras()])
yPred_relu = model.predict(xTest)
mae_relu = mean_absolute_error(yTest, yPred_relu)
mse_relu = mean_squared_error(yTest, yPred_relu)

# Reconfiguración del modelo para probar la función de activación Sigmoide
model = Sequential()
model.add(Dense(256, input_shape=(dims,), activation='sigmoid'))  # Capa con función de activación Sigmoide
model.add(Dense(256, activation='sigmoid'))  # Capa con función de activación Sigmoide
model.add(Dense(output_var, activation='sigmoid'))  # Capa de salida con función de activación Sigmoide
# Compilación y entrenamiento para Sigmoide
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xTrain, yTrain, validation_data=(X_val, Y_val), epochs=40, callbacks=[PlotLossesKeras()])
yPred_sigmoid = model.predict(xTest)
mae_sigmoid = mean_absolute_error(yTest, yPred_sigmoid)
mse_sigmoid = mean_squared_error(yTest, yPred_sigmoid)

# Reconfiguración del modelo para probar la función de activación Lineal
model = Sequential()
model.add(Dense(256, input_shape=(dims,), activation='linear'))  # Capa con función de activación Lineal
model.add(Dense(256, activation='linear'))  # Capa con función de activación Lineal
model.add(Dense(output_var, activation='linear'))  # Capa de salida con función de activación Lineal
# Compilación y entrenamiento para Lineal
model.compile(optimizer='sgd', loss='mean_squared_error')
model.fit(xTrain, yTrain, validation_data=(X_val, Y_val), epochs=40, callbacks=[PlotLossesKeras()])
yPred_linear = model.predict(xTest)
mae_linear = mean_absolute_error(yTest, yPred_linear)
mse_linear = mean_squared_error(yTest, yPred_linear)

print("40 epocas, optimizador sgd, neuronas 256")
print("Resultados con función de activación RELU:")
print("Error absoluto medio (MAE) RELU:", mae_relu)
print("Error cuadrático medio (MSE) RELU:", mse_relu)

print("\nResultados con función de activación Sigmoide:")
print("Error absoluto medio (MAE) Sigmoide:", mae_sigmoid)
print("Error cuadrático medio (MSE) Sigmoide:", mse_sigmoid)

print("\nResultados con función de activación Linear:")
print("Error absoluto medio (MAE) Linear:", mae_linear)
print("Error cuadrático medio (MSE) Linear:", mse_linear)
# Out:
# Loss
# 	training         	 (min:    0.004, max:    0.301, cur:    0.004)
# 	validation       	 (min:    0.004, max:    0.098, cur:    0.004)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0047 - val_loss: 0.0041
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 40 epocas, optimizador sgd, neuronas 256
# Resultados con función de activación RELU:
# Error absoluto medio (MAE) RELU: 0.06687683976491293
# Error cuadrático medio (MSE) RELU: 0.006889859356254935
#
# Resultados con función de activación Sigmoide:
# Error absoluto medio (MAE) Sigmoide: 0.11264125148455302
# Error cuadrático medio (MSE) Sigmoide: 0.02061777927758233
#
# Resultados con función de activación Linear:
# Error absoluto medio (MAE) Linear: 0.04227116885185242
# Error cuadrático medio (MSE) Linear: 0.003467141389335219

# %%
#CONFIGURACION FINAL DE LA RED NEURONAL DE DOS CAPAS 
#40 épocas, neuronas:256,optimizador:sgd y funcion de pérdida:linear
output_var = 1
print(output_var, ' output variables')

# # Definición de dimensiones de entrada
dims = xTrain.shape[1]
print(dims, 'input variables')

K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='linear'))
model.add(Dense(256,activation='linear'))
model.add(Dense(output_var))
model.add(Activation('linear'))
# Impresión de la arquitectura de la red neuronal
print(model.summary())

# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
#se escoge sgd debido a que con el se obtuvieron mejores resultados en el punto1 para este set de datos
model.compile(optimizer='sgd', loss='mean_squared_error')
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
xTrain, X_val, yTrain, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)
# Entrenamiento de la red neuronal con 40 épocas, de acuerdo a los resultados obtenidos en el punto1
model.fit(xTrain, yTrain,
          validation_data = (X_val, Y_val),
          epochs=40, 
          callbacks=[PlotLossesKeras()])
#Evaluando el desempeño de la red_neuronal 
yPred2 = model.predict(xTest)
mae2 = mean_absolute_error(yTest, yPred2)
print("Error absoluto medio (MAE) 2:", mae2)
mse2 = mean_squared_error(yTest, yPred2_1)
print("Error cuadrático medio (MSE) 2:", mse2)
# Out:
# Loss
# 	training         	 (min:    0.004, max:    0.354, cur:    0.004)
# 	validation       	 (min:    0.002, max:    0.157, cur:    0.002)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0041 - val_loss: 0.0022
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Error absoluto medio (MAE) 2: 0.04116972964604697
# Error cuadrático medio (MSE) 2: 0.006614071941612282

# %%
#prueba con earlystopping para la mejor combinacion probada de parámetros
from keras.callbacks import EarlyStopping, ModelCheckpoint
output_var = 1
print(output_var, ' output variables')

# # Definición de dimensiones de entrada
dims = xTrain.shape[1]
print(dims, 'input variables')

K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='linear'))
model.add(Dense(256,activation='linear'))
model.add(Dense(output_var))
model.add(Activation('linear'))
# Impresión de la arquitectura de la red neuronal
print(model.summary())

# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
#se escoge sgd debido a que con el se obtuvieron mejores resultados en el punto1 para este set de datos
model.compile(optimizer='sgd', loss='mean_squared_error')
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
xTrain, X_val, yTrain, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)
# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1) 
# Definición de la función ModelCheckpoint para guardar el modelo con mejor desempeño
fBestModel = 'best_model.keras'
best_model = ModelCheckpoint(fBestModel, verbose=0, save_best_only=True)
# Entrenamiento de la red neuronal con 40 épocas, de acuerdo a los resultados obtenidos en el punto1
model.fit(xTrain, yTrain,
          validation_data = (X_val, Y_val),
          epochs=40, 
          callbacks=[best_model, early_stop,PlotLossesKeras()])
#Evaluando el desempeño de la red_neuronal 
yPred2SE = model.predict(xTest)
mae2SE = mean_absolute_error(yTest, yPred2SE)
print("Error absoluto medio (MAE) 2se:", mae2SE)
mse2SE = mean_squared_error(yTest, yPred2SE)
print("Error cuadrático medio (MSE) 2se:", mse2SE)
# Out:
# Loss
# 	training         	 (min:    0.004, max:    0.368, cur:    0.004)
# 	validation       	 (min:    0.006, max:    0.183, cur:    0.007)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0035 - val_loss: 0.0068
# Epoch 7: early stopping
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Error absoluto medio (MAE) 2se: 0.04523685075441996
# Error cuadrático medio (MSE) 2se: 0.0035524932839540034

# %% [markdown]
# ### Proceso punto 2
#
# del punto 1 se tomaron los valores para el numero de épocas como 40 y el optimizador escogido fue sgd, debido a que se trata de un problema de regresión se escogió par las pruebas la función de pérdida error cuadrado medio( loss='mean_squared_error').
# la prueba numero 1 se realizó con los parámetros anteriores y el numero de neuronas fijado en 256, considerandose adecuado para la complejidad del problema y los 500 datos disponibles.
#
# Posteriormente se probó con un numero menor de neuronas 128, sin embargo esto produjo un ligero aumento en los errores absoluto y cuadrático medio, por lo cual se decide continuar los ensayos con 256 neuronas.
#
# La siguiente prueba consistión en probar diferentes funciones de activación, RELU que fue la que se usó en las pruebas anteriores y que es adecuada para este tipo de problemas de regresión , se probó sigmoide a pesar de ser más adecuada para problemas de clasificación, no obstante en este caso como se trataba de probabilidades, se evaluó su desempeño,finalmente se incluyó la funcion linear debido  a que las variables predictoras tienen correlaciones entre moderada y alta con la variable objetivo.
#
# Finalmente se definieron los mejores parámetros establecidos dentro del conjunto de pruebas (optimizador:SGD, épocas:40, funcion de perdida:MSE y neuronas:256) se determinaron MAE y MSE.
#
# Se realizó una prueba final aplicando Earlystopping, sin embargo los resultados obtenidos en cuanto a perdida no fueron mejores y en cuanto a MSE disminuyó a la mitad y MAE disminuyó en una pequeña fracción. En general para este caso se consideran los resultados en terminos de ajuste del modelo fueron más satisfactorios sin Earlystopping.

# %% [markdown]
# ## Punto 3  - Red Neuronal multicapa
#
# En la celda 3 creen **una red neuronal con más de una capa con la librería Keras, usando early stopping y dropout,** que prediga la probabilidad de admisión de los estudiantes con los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Normalização das variáveis preditoras
scaler = StandardScaler()
xTrain_scaled = scaler.fit_transform(xTrain)
xTest_scaled = scaler.transform(xTest)

# Definições iniciais
input_dim = xTrain_scaled.shape[1]
output_var = 1
epochs = 40

# Configurações para testes
configurations = [
    {'neurons': 128, 'dropout': 0.2, 'activation': 'linear', 'optimizer': 'sgd'},
    {'neurons': 128, 'dropout': 0.5, 'activation': 'linear', 'optimizer': 'sgd'},
    {'neurons': 256, 'dropout': 0.2, 'activation': 'linear', 'optimizer': 'sgd'},
    {'neurons': 256, 'dropout': 0.5, 'activation': 'linear', 'optimizer': 'adam'}
]

results = {}

for config in configurations:
    model = Sequential([
        Dense(config['neurons'], input_dim=input_dim, activation=config['activation']),
        Dropout(config['dropout']),
        Dense(config['neurons'], activation=config['activation']),
        Dropout(config['dropout']),
        Dense(output_var, activation='linear')
    ])
    
    model.compile(optimizer=config['optimizer'], loss='mean_squared_error')
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1)
    
    history = model.fit(xTrain_scaled, yTrain, validation_split=0.2, epochs=epochs, verbose=0, callbacks=[early_stopping])
    
    yPred = model.predict(xTest_scaled)
    mae = mean_absolute_error(yTest, yPred)
    mse = mean_squared_error(yTest, yPred)
    
    results[f"Config {config}"] = {
        'MAE': mae,
        'MSE': mse,
        'History': history.history
    }

# Imprimir resultados
for key, value in results.items():
    print(f"{key}: MAE = {value['MAE']}, MSE = {value['MSE']}")


# Loop através de cada configuração e seus dados para plotar separadamente
for config, data in results.items():
    plt.figure(figsize=(10, 5))  # Cria uma nova figura para cada configuração
    plt.plot(data['History']['loss'], label='Training Loss')
    plt.plot(data['History']['val_loss'], label='Validation Loss')
    plt.title('Loss')  # Alterado para mostrar apenas 'Loss'
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


# Plotar a perda de treinamento e validação
plt.figure(figsize=(10, 5))
for config, data in results.items():
    plt.plot(data['History']['loss'], label=f"{config} - Training")
    plt.plot(data['History']['val_loss'], label=f"{config} - Validation")

plt.title('Loss per Epoch for Different Configurations')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# # Imprimir as métricas MAE e MSE para cada configuração
# for config, metrics in results.items():
#     print(f"{config}: MAE = {metrics['MAE']:.4f}, MSE = {metrics['MSE']:.4f}")
# Out:
# 2024-05-10 20:21:54.803181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-10 20:21:54.804056: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 13: early stopping
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 13: early stopping
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 12: early stopping
# ...

# %% [markdown]
# A partir de las lecciones aprendidas en los puntos anteriores, se avanzó con la experimentación en la arquitectura de redes neuronales multicapa, integrando técnicas como Early Stopping y Dropout para optimizar la generalización y el rendimiento del modelo. Se mantuvieron las 40 épocas y el SGD como optimizador, fundamentado por su efectividad demostrada en el test del primer punto y su adecuación para problemas de regresión.
#
# La primera configuración evaluada utilizó 256 neuronas con una tasa de Dropout de 0.2, ofreciendo un buen equilibrio entre capacidad y regularización dada la complejidad del dataset de 500 registros. Al incrementar la tasa de Dropout a 0.5 con el mismo número de neuronas, se observó una variación en el rendimiento que sugiere un límite en la utilidad del aumento de Dropout para esta configuración particular.
#
# Posteriormente, se exploró reducir el número de neuronas a 128 con distintas tasas de Dropout (0.2 y 0.5). Aunque estas configuraciones resultaron en un aumento de los errores MAE y MSE, proporcionaron datos valiosos sobre cómo la reducción de la complejidad del modelo afecta su habilidad para capturar las relaciones entre los datos.
#
# Se decidió emplear la función de activación 'linear' en todas las capas. Esta decisión se basó en la naturaleza de la variable objetivo, siendo un valor continuo de probabilidad, teniendo en cuenta que en el punto 2 fue la que obtuvo mejor métricas.

# %% [markdown]
# ## Punto 4 - Comparación y análisis de resultados
#
# En la celda 4 comparen los resultados obtenidos de las diferentes redes y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datos de los resultados de precisión de los diferentes modelos para MAE
resultados_mae = {
    'Modelo': [
        'Red Neuronal de una capa - SGD, RMStrop',
        'Red Neuronal multicapa - SGD, 256 neuronas',
        'Red Neuronal multicapa (early stopping y dropout) - SGD, 256 neuronas'
    ],
    'MAE': [0.0431, 0.0411, 0.0592]
}

# Crea un DataFrame con los resultados de MAE
df_resultados_mae = pd.DataFrame(resultados_mae)

# Visualización para MAE
plt.figure(figsize=(12, 7))
barras = plt.bar(df_resultados_mae['Modelo'], df_resultados_mae['MAE'], color='darkblue')

# Añade etiquetas sobre cada barra con el valor de MAE
for barra in barras:
    y_valor = barra.get_height()  # Altura de la barra, es el valor de MAE
    x_pos = barra.get_x() + barra.get_width() / 2  # Posición X de la barra
    plt.text(x_pos, y_valor + 0.002, f'{y_valor:.4f}', ha='center', va='bottom')

plt.xlabel('Modelo')
plt.ylabel('MAE')  # Correcta etiqueta de eje Y
plt.title('Comparación del MAE de los Modelos de Redes Neuronales')
plt.ylim(0, 0.08)  # Ajusta el límite del eje Y para mejor visibilidad
plt.xticks(rotation=45, ha='right')
plt.show()

# Datos de los resultados para MSE
resultados_mse = {
    'Modelo': [
        'Red Neuronal de una capa - SGD, RMStrop',
        'Red Neuronal multicapa - SGD, 256 neuronas',
        'Red Neuronal multicapa (early stopping y dropout) - SGD, 256 neuronas'
    ],
    'MSE': [0.00340, 0.00661, 0.00600]
}

# Crea un DataFrame con los resultados de MSE
df_resultados_mse = pd.DataFrame(resultados_mse)

# Visualización para MSE
plt.figure(figsize=(12, 7))
barras = plt.bar(df_resultados_mse['Modelo'], df_resultados_mse['MSE'], color='darkblue')

# Añade etiquetas sobre cada barra con el valor de MSE
for barra in barras:
    y_valor = barra.get_height()  # Altura de la barra, es el valor de MSE
    x_pos = barra.get_x() + barra.get_width() / 2  # Posición X de la barra
    plt.text(x_pos, y_valor + 0.0002, f'{y_valor:.4f}', ha='center', va='bottom')  # Corrige la posición

plt.xlabel('Modelo') 
plt.ylabel('MSE')  # Correcta etiqueta de eje Y
plt.title('Comparación del MSE de los Modelos de Redes Neuronales')  # Título correcto
plt.ylim(0, 0.007)  # Ajusta el límite del eje Y
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Para la selección y evalución del modelo de este taller, se priorizó aquel más robusto frente a los valores más atipicos, y con la capacidad de predicción promedio optima, de manera que el MAE es el indicador ideal para la comparación. Teniendo en cuenta el anterior, la metodologia que nos generó menor error absoluto medio (MAE) fue la red neuronal con 2 capas sin usar el early stopping y dropout, esto nos sugiere que para este dataset el uso de early stopping y dropout comienza a generar overfitting en los resultados, haciendolo menos confiable para predicciones para nuevos datasets.
